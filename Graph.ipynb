# %%
#preparing dictionary

class Graph:
    def __init__(self, edges):
        self.edges = edges
        self.graph_dict = {}
        for start, end in self.edges:
            if start in self.graph_dict:
                self.graph_dict[start].append(end)
            else:
                self.graph_dict[start] = [end]
        print("Graph dict:",self.graph_dict)
        
if __name__ == '__main__':
    routes = [
        ("Mumbai", "Paris"),
        ("Mumbai", "Dubai"),
        ("Paris", "Dubai"),
        ("Paris", "New York"),
        ("Dubai", "New York"),
        ("New York", "Toronto")]
    
    route_graph = Graph(routes)
    
    #From Mumbai, 2 possible paths - Paris and Dubai
    d = {
        "Mumbai": ["Paris","Dubai"],
        "Paris" : ["Dubai","New York"]}
# Out:
# Graph dict: {'Mumbai': ['Paris', 'Dubai'], 'Paris': ['Dubai', 'New York'], 'Dubai': ['New York'], 'New York': ['Toronto']}

# %%
# 

class Graph:
    def __init__(self, edges):
        self.edges = edges
        self.graph_dict = {}
        for start, end in self.edges:
            if start in self.graph_dict:
                self.graph_dict[start].append(end)
            else:
                self.graph_dict[start] = [end]
        print("Graph dict:",self.graph_dict)
        
#take start and end as i/p and return all paths
    def get_paths(self, start, end, path=[]): #recursive function
        path = path + [start]
        if start == end:
            return [path]
        
        
if __name__ == '__main__':
    routes = [
        ("Mumbai", "Paris"),
        ("Mumbai", "Dubai"),
        ("Paris", "Dubai"),
        ("Paris", "New York"),
        ("Dubai", "New York"),
        ("New York", "Toronto")]
    
    route_graph = Graph(routes)
    
    start = "Mumbai"
    end = "Mumbai"
    print(f"Paths between {start} and {end}: ", route_graph.get_paths(start,end))
# Out:
# Graph dict: {'Mumbai': ['Paris', 'Dubai'], 'Paris': ['Dubai', 'New York'], 'Dubai': ['New York'], 'New York': ['Toronto']}
# Paths between Mumbai and Mumbai:  [['Mumbai']]

# %% [markdown]
# If there are no routes for a given start and end.
# Keys are the starting points

# %%
class Graph:
    def __init__(self, edges):
        self.edges = edges
        self.graph_dict = {}
        for start, end in self.edges:
            if start in self.graph_dict:
                self.graph_dict[start].append(end)
            else:
                self.graph_dict[start] = [end]
        print("Graph dict:",self.graph_dict)
        
#take start and end as i/p and return all paths
    def get_paths(self, start, end, path=[]): #recursive function
        path = path + [start]
        if start == end:
            return [path]
        
        
        if start not in self.graph_dict:
            return[]
        
        
if __name__ == '__main__':
    routes = [
        ("Mumbai", "Paris"),
        ("Mumbai", "Dubai"),
        ("Paris", "Dubai"),
        ("Paris", "New York"),
        ("Dubai", "New York"),
        ("New York", "Toronto")]
    
    route_graph = Graph(routes)
    
    start = "Toronto"
    end = "Mumbai"
    print(f"Paths between {start} and {end}: ", route_graph.get_paths(start,end))
# Out:
# Graph dict: {'Mumbai': ['Paris', 'Dubai'], 'Paris': ['Dubai', 'New York'], 'Dubai': ['New York'], 'New York': ['Toronto']}
# Paths between Toronto and Mumbai:  []

# %%
class Graph:
    def __init__(self, edges):
        self.edges = edges
        self.graph_dict = {}
        for start, end in self.edges:
            if start in self.graph_dict:
                self.graph_dict[start].append(end)
            else:
                self.graph_dict[start] = [end]
        print("Graph dict:",self.graph_dict)
        
#take start and end as i/p and return all paths
    def get_paths(self, start, end, path=[]): #recursive function
        path = path + [start]
        if start == end:
            return [path]
        
        
        if start not in self.graph_dict:
            return[]
        
        paths = []
        for node in self.graph_dict[start]:
            if node not in path:
                new_paths = self.get_paths(node, end, path)
                for p in new_paths:
                    paths.append(p)
        return paths
        
        
        
if __name__ == '__main__':
    routes = [
        ("Mumbai", "Paris"),
        ("Mumbai", "Dubai"),
        ("Paris", "Dubai"),
        ("Paris", "New York"),
        ("Dubai", "New York"),
        ("New York", "Toronto")]
    
    route_graph = Graph(routes)
    
    start = "Mumbai"
    end = "New York"
    print(f"Paths between {start} and {end}: ", route_graph.get_paths(start,end))
# Out:
# Graph dict: {'Mumbai': ['Paris', 'Dubai'], 'Paris': ['Dubai', 'New York'], 'Dubai': ['New York'], 'New York': ['Toronto']}
# Paths between Mumbai and New York:  [['Mumbai', 'Paris', 'Dubai', 'New York'], ['Mumbai', 'Paris', 'New York'], ['Mumbai', 'Dubai', 'New York']]

# %% [markdown]
# The above is the printing of all-paths; not based on weight

# %% [markdown]
# Now we will find shortest path based on min number of stops; again not based on weight

# %%
class Graph:
    def __init__(self, edges):
        self.edges = edges
        self.graph_dict = {}
        for start, end in self.edges:
            if start in self.graph_dict:
                self.graph_dict[start].append(end)
            else:
                self.graph_dict[start] = [end]
        print("Graph dict:",self.graph_dict)
        
#take start and end as i/p and return all paths
    def get_paths(self, start, end, path=[]): #recursive function
        path = path + [start]
        if start == end:
            return [path]
        
        
        if start not in self.graph_dict:
            return[]
        
        paths = []
        for node in self.graph_dict[start]:
            if node not in path:
                new_paths = self.get_paths(node, end, path)
                for p in new_paths:
                    paths.append(p)
        return paths
        
        
    def get_shortest_path(self,start,end,path=[]):
        path = path + [start]
        
        if start == end:
            return path  #if path is New York to New York
        
        
        if start not in self.graph_dict: #From Toronto there is no path
            return None
        
        shortest_path = None
        for node in self.graph_dict[start]: #recursive for loop
            if node not in path:
                sp = self.get_shortest_path(node, end, path)
                if sp:
                    if shortest_path is None or  len(sp) < len(shortest_path):
                        shortest_path = sp
                        
        return shortest_path
    
if __name__ == '__main__':
    routes = [
        ("Mumbai", "Paris"),
        ("Mumbai", "Dubai"),
        ("Paris", "Dubai"),
        ("Paris", "New York"),
        ("Dubai", "New York"),
        ("New York", "Toronto")]
    
    route_graph = Graph(routes)
    
    start = "Mumbai"
    end = "New York"
    print(f"Paths between {start} and {end}: ", route_graph.get_shortest_path(start,end))
# Out:
# Graph dict: {'Mumbai': ['Paris', 'Dubai'], 'Paris': ['Dubai', 'New York'], 'Dubai': ['New York'], 'New York': ['Toronto']}
# Paths between Mumbai and New York:  ['Mumbai', 'Paris', 'New York']

# %% [markdown]
# # Depth First Search

# %% [markdown]
# - DFS is a graph traversal algo
# - When given a choice it goes deeper into a graph
# - Backtrack if there is a deadend
# - Works on both directed and undirected graphs

# %%
class Vertex:
    def __init__(self, n): #constructor tankes name n
        self.name = n #assign to variable self.name
        self.neighbours = list()
        self.discovery = 0
        self.finish = 0
        self.color = 'black'

    def add_neighbour (self, v):
        nset = set(self.neighbours)
        if v not in nset:
            self.neighbours.append(v)
            self.neighbours.sort()
            
class Graph:
    vertices = {}
    time = 0
    
    def add_vertex(self, vertex):
        #vertex variable is actually a vertex object
        # and the name is not already in vertices list
        #then add to vertices list and return True
        if isinstance(vertex, Vertex) and vertex.name not in self.vertices:
            self.vertices[vertex.name] = vertex
            return True
        else:
            return False
        
    
    def add_edge(self, u, v):
        #check if u and v are existing vertices in graph
        if u in self.vertices and v in self.vertices:
            for key, value in self.vertices.items():
                if key == u:
                    value.add_neighbour(v)
                if key == v:
                    value.add_neighbour(u)
            
            
            return True
        
        else:
            
            return False
        
        
    def print_graph(self):
        for key in sorted(list(self.vertices.keys())):
            print(key + str(self.vertices[key].neighbours)+ "  " + str(self.vertices[key].discovery) + "/" + str(self.vertices[key].finish))
#recursive 

    def _dfs(self, vertex):
        global time
        vertex.color = 'red'
        vertex.discovery = time
        time += 1
        for v in vertex.neighbours:
            if self.vertices[v].color == 'black':
                self._dfs(self.vertices[v])
                
        vertex.color = 'blue'
        vertex.finish = time
        time += 1

        #initialize time to 1
        #passes vertex to recursive function
    def dfs(self, vertex):
        global time
        time = 1
        self._dfs(vertex)
        
g = Graph()
#adding vertex to the graph
a = Vertex('A') #variable name a
g.add_vertex(a) #add to the graph

#another way to add vertex to the graph
g.add_vertex(Vertex('B'))
#add a whole series of vertices if they are in order
for i in range(ord('A'), ord('K')):
    g.add_vertex(Vertex(chr(i)))

#list of strings representing edges
edges = ['AB','AE','BF','CG','DE','DH','EH','FG','FI','FJ','GJ','HI']

for edge in edges:
    g.add_edge(edge[:1], edge[1:])
    
g.dfs(a)
g.print_graph()
# Out:
# A['B', 'E']  1/20
# B['A', 'F']  2/19
# C['G']  5/6
# D['E', 'H']  12/15
# E['A', 'D', 'H']  13/14
# F['B', 'G', 'I', 'J']  3/18
# G['C', 'F', 'J']  4/9
# H['D', 'E', 'I']  11/16
# I['F', 'H']  10/17
# J['F', 'G']  7/8
